# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
## read in data
home = os.getcwd()
os.path.dirname(home)
df = pd.read_csv(f'{os.path.dirname(home)}/data/sleepstudy.csv')
df.head()
# Out:
#      Reaction  Days  Subject
# 0    249.5600     0      308
# 1    258.7047     1      308
# 2    250.8006     2      308
# 3    321.4398     3      308
# 4    356.8519     4      308
# ..        ...   ...      ...
# 175  329.6076     5      372
# 176  334.4818     6      372
# 177  343.2199     7      372
# 178  369.1417     8      372
# 179  364.1236     9      372
#
# [180 rows x 3 columns]

# %%
# explore response variable
sns.histplot(df['Reaction'])
# Out:
# <Axes: xlabel='Reaction', ylabel='Count'>

# %%
# explore input variable
plt.figure(figsize=(10,6))
sns.lineplot(x='Reaction', y='Days', data = df)
# Out:
# <Axes: xlabel='Reaction', ylabel='Days'>

# %%
# explore repeated measures - do we have enough data per subject?
plt.figure(figsize=(10,6))
sns.countplot(x='Subject', data = df)
# Out:
# <Axes: xlabel='Subject', ylabel='count'>

# %% [markdown]
# # COMMENTS
# ## response:
# ### looks fairly gaussian with no coonstraints no need to any link function based model (GLMM)
# ## predictors:
# ### Days - very complex looking relationship use a GAMM (although still test against a baseline LMM)
# ## repeated measure:
# ### sufficient data per subject
